# %%
import pandas as pd
import numpy as np

# %%
dataSet = pd.read_csv("Alzheimer.csv")
dataSet.head()
# Out:
#       HN         Education   age  hypertension  heart_disease family history  \
# 0  11046  Secondary School  67.0             0              1            Yes
# 1  51676          Bachelor  61.0             0              0            Yes
# 2  35112  Secondary School  80.0             0              1            Yes
# 3  67182          Bachelor  49.0             0              0            Yes
# 4   1665          Bachelor  79.0             1              0            Yes
#
#   Occupation Triglycerides  Blood Sugar   BMI   smoking_status  alzheimer
# 0    Private        Normal       228.69  36.6  formerly smoked          1
# 1  Freelance          High       202.21   NaN     never smoked          1
# 2    Private          High       105.92  32.5     never smoked          1
# 3    Private        Normal       171.23  34.4           smokes          1
# 4  Freelance          High       174.12  24.0     never smoked          1

# %% [markdown]
# # MARK: Data Processing

# %%
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4100 entries, 0 to 4099
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HN              4100 non-null   int64
#  1   Education       4100 non-null   object
#  2   age             4100 non-null   float64
#  3   hypertension    4100 non-null   int64
#  4   heart_disease   4100 non-null   int64
#  5   family history  4100 non-null   object
#  6   Occupation      4100 non-null   object
#  7   Triglycerides   4100 non-null   object
#  8   Blood Sugar     4100 non-null   float64
#  9   BMI             3936 non-null   float64
#  10  smoking_status  4100 non-null   object
#  11  alzheimer       4100 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 384.5+ KB

# %%
dataSet.isna().sum()
# Out:
# HN                  0
# Education           0
# age                 0
# hypertension        0
# heart_disease       0
# family history      0
# Occupation          0
# Triglycerides       0
# Blood Sugar         0
# BMI               164
# smoking_status      0
# alzheimer           0
# dtype: int64

# %% [markdown]
# ### MARK: เลือกที่จะ drop ทิ้งเพราะว่า Null มีจำนวนไม่เยอะมาก ไม่มีผลต่อ data เท่าที่ควร และ ไม่สามารถหาค่า BMI มาแทนที่ได้เพราะไม่มี weight และ height ของผู้ป่วย

# %%
dataSet = dataSet.dropna()
dataSet.isna().sum()
# Out:
# HN                0
# Education         0
# age               0
# hypertension      0
# heart_disease     0
# family history    0
# Occupation        0
# Triglycerides     0
# Blood Sugar       0
# BMI               0
# smoking_status    0
# alzheimer         0
# dtype: int64

# %% [markdown]
# ### MARK: ตรวจสอบ Class Target จำนวนเหมาะสมกันหรือไม่

# %%
print("Target == 1 ->", len(dataSet.loc[dataSet["alzheimer"] == 1, "alzheimer"]))
# Out:
# Target == 1 -> 202

# %%
print("Target == 1 ->", len(dataSet.loc[dataSet["alzheimer"] == 0, "alzheimer"]))
# Out:
# Target == 1 -> 3734

# %% [markdown]
# ### MARK: ปรับข้อมูล เป็น 0,1

# %%
dataSet.head()
# Out:
#       HN         Education   age  hypertension  heart_disease family history  \
# 0  11046  Secondary School  67.0             0              1            Yes
# 2  35112  Secondary School  80.0             0              1            Yes
# 3  67182          Bachelor  49.0             0              0            Yes
# 4   1665          Bachelor  79.0             1              0            Yes
# 5  66889  Secondary School  81.0             0              0            Yes
#
#   Occupation Triglycerides  Blood Sugar   BMI   smoking_status  alzheimer
# 0    Private        Normal       228.69  36.6  formerly smoked          1
# 2    Private          High       105.92  32.5     never smoked          1
# 3    Private        Normal       171.23  34.4           smokes          1
# 4  Freelance          High       174.12  24.0     never smoked          1
# 5    Private        Normal       186.21  29.0  formerly smoked          1

# %%
dataSet['Education'].unique()
# Out:
# array(['Secondary School', 'Bachelor'], dtype=object)

# %%
dataSet["Education"] = dataSet["Education"].replace({'Bachelor': 1, 'Secondary School': 0})

# %%
dataSet['family history'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dataSet["family history"] = dataSet["family history"].replace({'Yes': 1, 'No': 0})

# %%
dataSet['Occupation'].unique()
# Out:
# array(['Private', 'Freelance', 'Officer', 'Farmer', 'Never_worked'],
#       dtype=object)

# %%
dataSet["Occupation"] = dataSet["Occupation"].replace({'Private': 0, 'Freelance': 1, "Officer":2, "Farmer":3, "Never_worked":4})

# %%
dataSet['Triglycerides'].unique()
# Out:
# array(['Normal', 'High'], dtype=object)

# %%
dataSet['Triglycerides'] = dataSet['Triglycerides'].replace({'High': 1,'Normal': 0})

# %%
dataSet["smoking_status"].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
dataSet["smoking_status"] = dataSet["smoking_status"].replace({'formerly smoked': 0, 'never smoked': 1, "smokes":2, "Unknown":3})

# %% [markdown]
# # MARK: แบ่งข้อมูล

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %% [markdown]
# ### MARK: train_test_split

# %%
X = dataSet.drop('alzheimer', axis=1)
y = dataSet["alzheimer"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# random_state 42 เพื่อข้อมูลเหมือนกันทุกครั้ง

# %%
# ลองใช้ Class target เท่ากัน ดู
# dataSetSendModel = dataSet.loc[:(len(dataSet.loc[dataSet["alzheimer"] == 1, "alzheimer"])-1)*2]
# X = dataSet.drop('alzheimer', axis=1)
# y = dataSet["alzheimer"]
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#          HN  Education   age  hypertension  heart_disease  family history  \
# 2837  22939          1  22.0             0              0               0
# 2069    464          0  46.0             0              0               1
# 1724  21724          1  42.0             0              0               1
# 1826   2868          1  54.0             0              0               1
# 514   42359          0   9.0             0              0               0
#
#       Occupation  Triglycerides  Blood Sugar   BMI  smoking_status
# 2837           0              1        80.72  29.3               3
# 2069           0              1        78.44  23.9               1
# 1724           1              0       124.34  34.7               0
# 1826           2              1       102.61  32.4               3
# 514            3              0       122.22  17.7               3

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2755 entries, 2837 to 3323
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HN              2755 non-null   int64
#  1   Education       2755 non-null   int64
#  2   age             2755 non-null   float64
#  3   hypertension    2755 non-null   int64
#  4   heart_disease   2755 non-null   int64
#  5   family history  2755 non-null   int64
#  6   Occupation      2755 non-null   int64
#  7   Triglycerides   2755 non-null   int64
#  8   Blood Sugar     2755 non-null   float64
#  9   BMI             2755 non-null   float64
#  10  smoking_status  2755 non-null   int64
# dtypes: float64(3), int64(8)
# memory usage: 258.3 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2755 entries, 2837 to 3323
# Series name: alzheimer
# Non-Null Count  Dtype
# --------------  -----
# 2755 non-null   int64
# dtypes: int64(1)
# memory usage: 43.0 KB

# %% [markdown]
# # Model 1 Decision tree

# %% [markdown]
# ### MARK: Decision tree model Start

# %%
clfModel = tree.DecisionTreeClassifier(criterion="gini",class_weight='balanced',random_state=42)

# %%
clfModel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=42)

# %%
# feature ที่มีความสำคัญ
fImportances = pd.Series(clfModel.feature_importances_, index=X_train.columns).sort_values(ascending=False)
fImportances
# Out:
# age               0.433373
# HN                0.212369
# Blood Sugar       0.163884
# BMI               0.110241
# smoking_status    0.028589
# Education         0.013869
# hypertension      0.009327
# Occupation        0.008413
# Triglycerides     0.007959
# heart_disease     0.006169
# family history    0.005806
# dtype: float64

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel.score(X_train,y_train))
# อันเดียวกัน
# y_train_pred = clf.predict(X_train)
# accuracy_score(y_train, y_train_pred)
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 1.0

# %% [markdown]
# ### MARK: Visualize Decision Tree

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel.fit(X_train, y_train))
plt.show()

# %% [markdown]
# ### MARK: Predict and Score Model

# %%
y_pred = clfModel.predict(X_test)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.9119390347163421

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0         0   1
# alzheimer
# 0          1064  50
# 1            54  13

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      1114
#            1       0.21      0.19      0.20        67
#
#     accuracy                           0.91      1181
#    macro avg       0.58      0.57      0.58      1181
# weighted avg       0.91      0.91      0.91      1181

# %% [markdown]
# ### MARK: feature_importances

# %%
np.array([X.columns.values.tolist(), list(clfModel.feature_importances_)]).T
# Out:
# array([['HN', '0.21236882048969727'],
#        ['Education', '0.013868764905737555'],
#        ['age', '0.43337287530759283'],
#        ['hypertension', '0.009327438481882328'],
#        ['heart_disease', '0.006169211583644582'],
#        ['family history', '0.005805918119254997'],
#        ['Occupation', '0.008413268036986148'],
#        ['Triglycerides', '0.007958726129293481'],
#        ['Blood Sugar', '0.16388436481066035'],
#        ['BMI', '0.11024122354823408'],
#        ['smoking_status', '0.028589388587016377']], dtype='<U32')

# %%
feature_names = X.columns.values.tolist()
importances = clfModel.feature_importances_
indices = np.argsort(importances)[::-1]

# %%
plt.figure(figsize=(10, 6))
plt.bar(range(X.shape[1]), importances[indices], align="center")
plt.xticks(range(X.shape[1]), [feature_names[i] for i in indices], rotation=90)
plt.xlabel("Feature_names")
plt.ylabel("Importances")
plt.title("Feature importances")
plt.show()

# %% [markdown]
# ### MARK: ลอง Puring + เลือก Feature importances 4 อันดับแรก เข้า model

# %%
from sklearn.model_selection import cross_val_score

# %%
feature_importances_Select = ['age', 'HN', 'Blood Sugar', 'BMI']

# %%
X_feature_importances = dataSet[feature_importances_Select]
y_feature_importances = y
X_trainIm, X_testIm, y_trainIm, y_testIm = train_test_split(X_feature_importances, y_feature_importances, test_size=0.3, random_state=42)

# %%
best_score = 0

for md in range(1, 10): # iterate different maximum depth values
    # train the model
    treeModel = tree.DecisionTreeClassifier(criterion="gini",class_weight='balanced', max_depth=md)
    # perform cross-validation
    scores = cross_val_score(treeModel, X_trainIm, y_trainIm, cv=10, scoring='accuracy')
   
    # compute mean cross-validation accuracy
    score = np.mean(scores)
    print("cross_val_score ->",score)
    
    # if we got a better score, store the score and parameters
    if score > best_score:
        best_score = score
        best_parameter = md
# Out:
# cross_val_score -> 0.6624413702239789
# cross_val_score -> 0.6624413702239789
# cross_val_score -> 0.7680737812911727
# cross_val_score -> 0.7575388669301713
# cross_val_score -> 0.7717061923583663
# cross_val_score -> 0.7873254281949935
# cross_val_score -> 0.8090816864295125
# cross_val_score -> 0.8214005270092226
# cross_val_score -> 0.8391870882740449

# %% [markdown]
# ### MARK: Select Feature importances Top 4

# %%
clfModel_Im = tree.DecisionTreeClassifier(criterion="gini",class_weight='balanced', random_state=42)

# %%
clfModel_Im.fit(X_trainIm, y_trainIm)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=42)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel_Im.score(X_trainIm,y_trainIm))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 1.0

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_Im.fit(X_trainIm, y_trainIm))
plt.show()

# %%
y_predIm = clfModel_Im.predict(X_testIm)
print("ตัวอย่างข้อมูลทดสอบ ->",accuracy_score(y_testIm, y_predIm))
# Out:
# ตัวอย่างข้อมูลทดสอบ -> 0.9170194750211685

# %%
pd.crosstab(y_testIm, y_predIm)
# Out:
# col_0         0   1
# alzheimer
# 0          1075  39
# 1            59   8

# %%
print("Classification Report:\n", classification_report(y_testIm, y_predIm))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      1114
#            1       0.17      0.12      0.14        67
#
#     accuracy                           0.92      1181
#    macro avg       0.56      0.54      0.55      1181
# weighted avg       0.90      0.92      0.91      1181

# %% [markdown]
# ### MARK: Select Feature + max_depth = best_parameter

# %%
print("best_parameter max_depth -> ",best_parameter)
# Out:
# best_parameter max_depth ->  9

# %%
clfModel_Im = tree.DecisionTreeClassifier(criterion="gini",class_weight='balanced', max_depth=best_parameter, random_state=42)

# %%
clfModel_Im.fit(X_trainIm, y_trainIm)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=9, random_state=42)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel_Im.score(X_trainIm,y_trainIm))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 0.8907441016333938

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_Im.fit(X_trainIm, y_trainIm))
plt.show()

# %%
y_predIm = clfModel_Im.predict(X_testIm)
print("ตัวอย่างข้อมูลทดสอบ ->",accuracy_score(y_testIm, y_predIm))
# Out:
# ตัวอย่างข้อมูลทดสอบ -> 0.834038950042337

# %%
pd.crosstab(y_testIm, y_predIm)
# Out:
# col_0        0    1
# alzheimer
# 0          953  161
# 1           35   32

# %%
print("Classification Report:\n", classification_report(y_testIm, y_predIm))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91      1114
#            1       0.17      0.48      0.25        67
#
#     accuracy                           0.83      1181
#    macro avg       0.57      0.67      0.58      1181
# weighted avg       0.92      0.83      0.87      1181

# %% [markdown]
# # Model 2 K nearest neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
k_values = [1, 3, 5, 7, 9, 11, 13, 15]

# %%
accuracy_scores = []

# %% [markdown]
# ### หา K ที่มีค่า accuracy ดีที่สุด

# %%
for k in k_values:
    # สร้างโมเดล K-Nearest Neighbors ด้วยค่า K ปัจจุบัน
    knn = KNeighborsClassifier(n_neighbors=k)
    
    # ทำการ Cross-validation และประเมินความถูกต้อง
    scores = cross_val_score(knn, X, y, cv=10) 
    accuracy = np.mean(scores)
    print("k",k,"->",accuracy)
    
    # เพิ่มค่าความถูกต้องลงในรายการ
    accuracy_scores.append(accuracy)
# Out:
# k 1 -> 0.915147053125121
# k 3 -> 0.9458861290864237
# k 5 -> 0.9479178775784348
# k 7 -> 0.9486792988982318
# k 9 -> 0.9486792988982318
# k 11 -> 0.9486792988982318
# k 13 -> 0.9486792988982318
# k 15 -> 0.9486792988982318

# %%
best_k = k_values[np.argmax(accuracy_scores)]
best_accuracy = max(accuracy_scores)
print(f"ค่า K ที่ดีที่สุดคือ {best_k} ด้วยความถูกต้อง {best_accuracy:.2f}")
# Out:
# ค่า K ที่ดีที่สุดคือ 7 ด้วยความถูกต้อง 0.95

# %% [markdown]
# ### MARK: ปรับ Scale

# %%
scaler = StandardScaler()

# %%
# X_scaler = scaler.fit_transform(dataSet.drop('alzheimer', axis=1))
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# ### MARK: KNN Start

# %%
knn = KNeighborsClassifier(n_neighbors=best_k)

# %%
knn.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 7,
#  'p': 2,
#  'weights': 'uniform'}

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
print("ตัวอย่างข้อมูลเรียนรู้ ->",knn.score(X_train,y_train))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.9520871143375681

# %% [markdown]
# ### MARK: Predict and Score Model

# %%
y_pred = knn.predict(X_test) 
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.9398814563928873

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1114
#            1       0.17      0.01      0.03        67
#
#     accuracy                           0.94      1181
#    macro avg       0.56      0.51      0.50      1181
# weighted avg       0.90      0.94      0.92      1181

# %% [markdown]
# ### MARK: เลือก Feature importances 4 อันดับแรก เข้า model

# %%
X_trainIm = scaler.fit_transform(X_trainIm)
X_testIm = scaler.fit_transform(X_testIm)

# %%
knn.fit(X_trainIm, y_trainIm)
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",knn.score(X_trainIm,y_trainIm))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 0.949546279491833

# %%
y_predIm = knn.predict(X_testIm)
print("ตัวอย่างข้อมูลทดสอบ ->",accuracy_score(y_testIm, y_predIm))
# Out:
# ตัวอย่างข้อมูลทดสอบ -> 0.9398814563928873

# %%
print("Classification Report:\n", classification_report(y_testIm, y_predIm))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1114
#            1       0.00      0.00      0.00        67
#
#     accuracy                           0.94      1181
#    macro avg       0.47      0.50      0.48      1181
# weighted avg       0.89      0.94      0.91      1181

# %% [markdown]
# # Model 3 Neural Network

# %%
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ### MARK: Neural Network Start

# %%
nnClf = MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=1000, random_state=42)

# %%
nnClf.get_params()
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': (64, 32),
#  'learning_rate': 'constant',
#  'learning_rate_init': 0.001,
#  'max_fun': 15000,
#  'max_iter': 1000,
#  'momentum': 0.9,
#  'n_iter_no_change': 10,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': 42,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
nnClf.fit(X_train,y_train)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",nnClf.score(X_train,y_train))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.9992740471869328

# %% [markdown]
# ### MARK: Predict and Score Model

# %%
y_pred = nnClf.predict(X_test) 
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.9178662150719729

# %%
# print("Classification Report:\n", classification_report(y_test, y_pred))
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      1114
#            1       0.16      0.10      0.13        67
#
#     accuracy                           0.92      1181
#    macro avg       0.55      0.54      0.54      1181
# weighted avg       0.90      0.92      0.91      1181

# %% [markdown]
# ### MARK: เลือก Feature importances 4 อันดับแรก เข้า model

# %%
nnClf.fit(X_trainIm, y_trainIm)
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",nnClf.score(X_trainIm,y_trainIm))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 0.9546279491833031

# %%
y_predIm = nnClf.predict(X_testIm)
print("ตัวอย่างข้อมูลทดสอบ ->",accuracy_score(y_testIm, y_predIm))
# Out:
# ตัวอย่างข้อมูลทดสอบ -> 0.9407281964436918

# %%
print("Classification Report:\n", classification_report(y_testIm, y_predIm))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1114
#            1       0.00      0.00      0.00        67
#
#     accuracy                           0.94      1181
#    macro avg       0.47      0.50      0.48      1181
# weighted avg       0.89      0.94      0.91      1181

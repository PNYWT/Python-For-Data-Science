# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('players.csv').loc[: , :'saves'].set_index('surname')
df
# Out:
#                   team    position  minutes  shots  passes  tackles  saves
# surname
# Abdoun         Algeria  midfielder       16      0       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# [595 rows x 7 columns]

# %% [markdown]
# # Sorting

# %%
df.sort_values('passes')
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# Barron           New Zealand  midfielder        1      0       0        0
# Konno                  Japan    defender        2      0       0        0
# Petras              Slovakia    defender        1      0       0        0
# Kim Dong-Jin     South Korea    defender        1      0       0        0
# Lee Seung-Yeoul  South Korea     forward        3      0       0        0
# ...                      ...         ...      ...    ...     ...      ...
# Pique                  Spain    defender      540      2     402       15
# Schweinsteiger       Germany  midfielder      531      5     423       23
# Alonso                 Spain  midfielder      506      9     465       18
# Busquets               Spain  midfielder      511      0     466       15
# Xavi                   Spain  midfielder      515      4     563        6
#
#                  saves
# surname
# Barron               0
# ...

# %%
df.sort_values('passes', ascending=False).head(20)
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# Xavi                   Spain  midfielder      515      4     563        6
# Busquets               Spain  midfielder      511      0     466       15
# Alonso                 Spain  midfielder      506      9     465       18
# Schweinsteiger       Germany  midfielder      531      5     423       23
# Pique                  Spain    defender      540      2     402       15
# Lahm                 Germany    defender      540      0     360       17
# Messi              Argentina     forward      450     21     321       10
# Capdevila              Spain    defender      540      1     310       10
# Annan                  Ghana  midfielder      510      4     307       11
# van Bommel       Netherlands  midfielder      540      2     307       31
# Iniesta                Spain  midfielder      437      8     299       11
# ...

# %%
df.sort_values( ['passes', 'shots'], ascending=[False, True] ).head(20)
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# Xavi                   Spain  midfielder      515      4     563        6
# Busquets               Spain  midfielder      511      0     466       15
# Alonso                 Spain  midfielder      506      9     465       18
# Schweinsteiger       Germany  midfielder      531      5     423       23
# Pique                  Spain    defender      540      2     402       15
# Lahm                 Germany    defender      540      0     360       17
# Messi              Argentina     forward      450     21     321       10
# Capdevila              Spain    defender      540      1     310       10
# van Bommel       Netherlands  midfielder      540      2     307       31
# Annan                  Ghana  midfielder      510      4     307       11
# Gilberto Silva        Brazil  midfielder      450      3     299       11
# ...

# %%
df.sort_index()
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# Abdoun               Algeria  midfielder       16      0       6        0
# Abe                    Japan  midfielder      351      0     101       14
# Abidal                France    defender      180      0      91        6
# Abou Diaby            France  midfielder      270      1     111        5
# Aboubakar           Cameroon     forward       46      2      16        0
# ...                      ...         ...      ...    ...     ...      ...
# de Zeeuw         Netherlands  midfielder       47      0      37        2
# van Bommel       Netherlands  midfielder      540      2     307       31
# van Bronckhorst  Netherlands    defender      540      1     271       10
# van Persie       Netherlands     forward      479     14     108        1
# von Bergen       Switzerland    defender      234      0      79        3
#
#                  saves
# surname
# Abdoun               0
# ...

# %%
df.sort_index(ascending=False)
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# von Bergen       Switzerland    defender      234      0      79        3
# van Persie       Netherlands     forward      479     14     108        1
# van Bronckhorst  Netherlands    defender      540      1     271       10
# van Bommel       Netherlands  midfielder      540      2     307       31
# de Zeeuw         Netherlands  midfielder       47      0      37        2
# ...                      ...         ...      ...    ...     ...      ...
# Aboubakar           Cameroon     forward       46      2      16        0
# Abou Diaby            France  midfielder      270      1     111        5
# Abidal                France    defender      180      0      91        6
# Abe                    Japan  midfielder      351      0     101       14
# Abdoun               Algeria  midfielder       16      0       6        0
#
#                  saves
# surname
# von Bergen           0
# ...

# %% [markdown]
# # Assignment

# %%
df
# Out:
#                   team    position  minutes  shots  passes  tackles  saves
# surname
# Abdoun         Algeria  midfielder       16      0       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# [595 rows x 7 columns]

# %%
df.loc['Abdoun', 'shots'] = 1

# %%
df
# Out:
#                   team    position  minutes  shots  passes  tackles  saves
# surname
# Abdoun         Algeria  midfielder       16      1       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# [595 rows x 7 columns]

# %%
df.sort_values('minutes')
# Out:
#                      team    position  minutes  shots  passes  tackles  saves
# surname
# Petras           Slovakia    defender        1      0       0        0      0
# Barron        New Zealand  midfielder        1      0       0        0      0
# Kim Dong-Jin  South Korea    defender        1      0       0        0      0
# Mesbah            Algeria  midfielder        1      0       1        0      0
# Eggimann      Switzerland    defender        1      0       0        0      0
# ...                   ...         ...      ...    ...     ...      ...    ...
# Forlan            Uruguay     forward      564     18     202        0      0
# Perez             Uruguay  midfielder      567      2     252       34      0
# Muslera           Uruguay  goalkeeper      570      0      75        0     16
# Maxi Pereira      Uruguay  midfielder      570      5     182       15      0
# Arevalo Rios      Uruguay  midfielder      570      5     195       21      0
#
# [595 rows x 7 columns]

# %%
df.loc[ df.minutes == 570, 'minutes' ]
# Out:
# surname
# Arevalo Rios    570
# Maxi Pereira    570
# Muslera         570
# Name: minutes, dtype: int64

# %%
df.loc[ df.minutes == 570, 'minutes' ] = 600 #broadcasting

# %%
df.sort_values('minutes')
# Out:
#                      team    position  minutes  shots  passes  tackles  saves
# surname
# Petras           Slovakia    defender        1      0       0        0      0
# Barron        New Zealand  midfielder        1      0       0        0      0
# Kim Dong-Jin  South Korea    defender        1      0       0        0      0
# Mesbah            Algeria  midfielder        1      0       1        0      0
# Eggimann      Switzerland    defender        1      0       0        0      0
# ...                   ...         ...      ...    ...     ...      ...    ...
# Forlan            Uruguay     forward      564     18     202        0      0
# Perez             Uruguay  midfielder      567      2     252       34      0
# Muslera           Uruguay  goalkeeper      600      0      75        0     16
# Maxi Pereira      Uruguay  midfielder      600      5     182       15      0
# Arevalo Rios      Uruguay  midfielder      600      5     195       21      0
#
# [595 rows x 7 columns]

# %%
df.loc[ df.minutes == 600, 'minutes']
# Out:
# surname
# Arevalo Rios    600
# Maxi Pereira    600
# Muslera         600
# Name: minutes, dtype: int64

# %%
df.loc[ df.minutes == 600, 'minutes'].sort_index()
# Out:
# surname
# Arevalo Rios    600
# Maxi Pereira    600
# Muslera         600
# Name: minutes, dtype: int64

# %%
df.loc[ df.minutes == 600, 'minutes'] = [570, 580, 590] #sequence assignment

# %%
df.sort_values('minutes')
# Out:
#                      team    position  minutes  shots  passes  tackles  saves
# surname
# Petras           Slovakia    defender        1      0       0        0      0
# Barron        New Zealand  midfielder        1      0       0        0      0
# Kim Dong-Jin  South Korea    defender        1      0       0        0      0
# Mesbah            Algeria  midfielder        1      0       1        0      0
# Eggimann      Switzerland    defender        1      0       0        0      0
# ...                   ...         ...      ...    ...     ...      ...    ...
# Forlan            Uruguay     forward      564     18     202        0      0
# Perez             Uruguay  midfielder      567      2     252       34      0
# Arevalo Rios      Uruguay  midfielder      570      5     195       21      0
# Maxi Pereira      Uruguay  midfielder      580      5     182       15      0
# Muslera           Uruguay  goalkeeper      590      0      75        0     16
#
# [595 rows x 7 columns]

# %% [markdown]
# # Arithmetic

# %%
df.shots
# Out:
# surname
# Abdoun           1
# Belhadj          1
# Boudebouz        3
# Bougherra        1
# Chaouchi         0
#                 ..
# Holden           0
# Howard           0
# Jozy Altidore    8
# Onyewu           1
# Torres           1
# Name: shots, Length: 595, dtype: int64

# %%
df.shots + 5 #broadcasting
# Out:
# surname
# Abdoun            6
# Belhadj           6
# Boudebouz         8
# Bougherra         6
# Chaouchi          5
#                  ..
# Holden            5
# Howard            5
# Jozy Altidore    13
# Onyewu            6
# Torres            6
# Name: shots, Length: 595, dtype: int64

# %%
df
# Out:
#                   team    position  minutes  shots  passes  tackles  saves
# surname
# Abdoun         Algeria  midfielder       16      1       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# [595 rows x 7 columns]

# %%
df.shots = df.shots + 5

# %%
df
# Out:
#                   team    position  minutes  shots  passes  tackles  saves
# surname
# Abdoun         Algeria  midfielder       16      6       6        0      0
# Belhadj        Algeria    defender      270      6     146        8      0
# Boudebouz      Algeria  midfielder       74      8      28        1      0
# Bougherra      Algeria    defender      270      6      89       11      0
# Chaouchi       Algeria  goalkeeper       90      5      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      5       2        0      0
# Howard             USA  goalkeeper      390      5      81        0     14
# Jozy Altidore      USA     forward      356     13      84        2      0
# Onyewu             USA    defender      170      6      69        2      0
# Torres             USA  midfielder       45      6      32        0      0
#
# [595 rows x 7 columns]

# %%
five_players_df = df.sample(5)
five_players_df
# Out:
#                  team    position  minutes  shots  passes  tackles  saves
# surname
# Sneijder  Netherlands  midfielder      532     20     279        7      0
# Makoun       Cameroon  midfielder      210      9     164        2      0
# Matsui          Japan  midfielder      273      8      95        4      0
# Busquets        Spain  midfielder      511      5     466       15      0
# Neuer         Germany  goalkeeper      540      5      99        0     20

# %%
c1 = five_players_df.shots
c1
# Out:
# surname
# Sneijder    20
# Makoun       9
# Matsui       8
# Busquets     5
# Neuer        5
# Name: shots, dtype: int64

# %%
five_players_df.tackles.sort_values()
# Out:
# surname
# Neuer        0
# Makoun       2
# Matsui       4
# Sneijder     7
# Busquets    15
# Name: tackles, dtype: int64

# %%
c2 = five_players_df.tackles.sort_values()
c2
# Out:
# surname
# Neuer        0
# Makoun       2
# Matsui       4
# Sneijder     7
# Busquets    15
# Name: tackles, dtype: int64

# %%
c1
# Out:
# surname
# Sneijder    20
# Makoun       9
# Matsui       8
# Busquets     5
# Neuer        5
# Name: shots, dtype: int64

# %%
c1+c2
# Out:
# surname
# Busquets    20
# Makoun      11
# Matsui      12
# Neuer        5
# Sneijder    27
# dtype: int64

# %%
c3 = c1.sample(3)
c3
# Out:
# surname
# Makoun       9
# Sneijder    20
# Neuer        5
# Name: shots, dtype: int64

# %%
c4 = c2.sample(3)
c4
# Out:
# surname
# Makoun      2
# Matsui      4
# Sneijder    7
# Name: tackles, dtype: int64

# %%
c3+c4
# Out:
# surname
# Makoun      11.0
# Matsui       NaN
# Neuer        NaN
# Sneijder    27.0
# dtype: float64

# %%
c3.add(c4, fill_value=0)
# Out:
# surname
# Makoun      11.0
# Matsui       4.0
# Neuer        5.0
# Sneijder    27.0
# dtype: float64

# %%
c3
# Out:
# surname
# Makoun       9
# Sneijder    20
# Neuer        5
# Name: shots, dtype: int64

# %%
c4
# Out:
# surname
# Makoun      2
# Matsui      4
# Sneijder    7
# Name: tackles, dtype: int64

# %% [markdown]
# # NaN

# %%
c5 = c3+c4
c5
# Out:
# surname
# Makoun      11.0
# Matsui       NaN
# Neuer        NaN
# Sneijder    27.0
# dtype: float64

# %%
c5.isna()
# Out:
# surname
# Makoun      False
# Matsui       True
# Neuer        True
# Sneijder    False
# dtype: bool

# %%
c5.isnull()
# Out:
# surname
# Makoun      False
# Matsui       True
# Neuer        True
# Sneijder    False
# dtype: bool

# %%
c5.loc[ c5.isna() ]
# Out:
# surname
# Matsui   NaN
# Neuer    NaN
# dtype: float64

# %%
~c5.isna()
# Out:
# surname
# Makoun       True
# Matsui      False
# Neuer       False
# Sneijder     True
# dtype: bool

# %%
c5.isna().sum()
# Out:
# 2

# %%
c5.loc[ c5.isna() ].shape[0]
# Out:
# 2

# %%
c5.fillna(0)
# Out:
# surname
# Makoun      11.0
# Matsui       0.0
# Neuer        0.0
# Sneijder    27.0
# dtype: float64

# %% [markdown]
# # Statistics

# %%
df = pd.read_csv('players.csv').loc[:, :'saves']

# %%
df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves
# 0        0
# 1        0
# 2        0
# 3        0
# 4        2
# ..     ...
# ...

# %%
df.shots.sum()
# Out:
# 1371

# %%
df.sum()
# Out:
# surname     AbdounBelhadjBoudebouzBougherraChaouchiDjebbou...
# team        AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# position    midfielderdefendermidfielderdefendergoalkeeper...
# minutes                                                124274
# shots                                                    1371
# passes                                                  50290
# tackles                                                  2494
# saves                                                     397
# dtype: object

# %%
df.sum(numeric_only=True)
# Out:
# minutes    124274
# shots        1371
# passes      50290
# tackles      2494
# saves         397
# dtype: int64

# %%
df.sum(numeric_only=True, axis=1)
# Out:
# 0       22
# 1      425
# 2      106
# 3      371
# 4      109
#       ...
# 590      6
# 591    485
# 592    450
# 593    242
# 594     78
# Length: 595, dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# minutes    208.863866
# shots        2.304202
# passes      84.521008
# tackles      4.191597
# saves        0.667227
# dtype: float64

# %%
df.max()
# Out:
# surname     von Bergen
# team           Uruguay
# position    midfielder
# minutes            570
# shots               27
# passes             563
# tackles             34
# saves               20
# dtype: object

# %%
df.passes.rank()
# Out:
# 0       37.5
# 1      492.0
# 2      142.0
# 3      377.5
# 4       89.0
#        ...
# 590     12.5
# 591    358.0
# 592    367.0
# 593    317.0
# 594    160.0
# Name: passes, Length: 595, dtype: float64

# %%
df.passes.max()
# Out:
# 563

# %%
df.passes.idxmax()
# Out:
# 536

# %%
df.iloc[536,:]
# Out:
# surname           Xavi
# team             Spain
# position    midfielder
# minutes            515
# shots                4
# passes             563
# tackles              6
# saves                0
# Name: 536, dtype: object

# %%
df.shots.idxmin()
# Out:
# 0

# %%
df.loc[ : , 'minutes':] + 5
# Out:
#      minutes  shots  passes  tackles  saves
# 0         21      5      11        5      5
# 1        275      6     151       13      5
# 2         79      8      33        6      5
# 3        275      6      94       16      5
# 4         95      5      22        5      7
# ..       ...    ...     ...      ...    ...
# 590        9      5       7        5      5
# 591      395      5      86        5     19
# 592      361     13      89        7      5
# 593      175      6      74        7      5
# 594       50      6      37        5      5
#
# [595 rows x 5 columns]

# %% [markdown]
# # drop / insert col/row

# %%
df.iloc[:,:-1]
# Out:
#            surname     team    position  minutes  shots  passes  tackles
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
# [595 rows x 7 columns]

# %%
df.drop('shots', axis=1)
# Out:
#            surname     team    position  minutes  passes  tackles  saves
# 0           Abdoun  Algeria  midfielder       16       6        0      0
# 1          Belhadj  Algeria    defender      270     146        8      0
# 2        Boudebouz  Algeria  midfielder       74      28        1      0
# 3        Bougherra  Algeria    defender      270      89       11      0
# 4         Chaouchi  Algeria  goalkeeper       90      17        0      2
# ..             ...      ...         ...      ...     ...      ...    ...
# 590         Holden      USA  midfielder        4       2        0      0
# 591         Howard      USA  goalkeeper      390      81        0     14
# 592  Jozy Altidore      USA     forward      356      84        2      0
# 593         Onyewu      USA    defender      170      69        2      0
# 594         Torres      USA  midfielder       45      32        0      0
#
# [595 rows x 7 columns]

# %%
df.drop(['shots','saves'], axis=1)
# Out:
#            surname     team    position  minutes  passes  tackles
# 0           Abdoun  Algeria  midfielder       16       6        0
# 1          Belhadj  Algeria    defender      270     146        8
# 2        Boudebouz  Algeria  midfielder       74      28        1
# 3        Bougherra  Algeria    defender      270      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      17        0
# ..             ...      ...         ...      ...     ...      ...
# 590         Holden      USA  midfielder        4       2        0
# 591         Howard      USA  goalkeeper      390      81        0
# 592  Jozy Altidore      USA     forward      356      84        2
# 593         Onyewu      USA    defender      170      69        2
# 594         Torres      USA  midfielder       45      32        0
#
# [595 rows x 6 columns]

# %%
df.drop([2,3,5,7], axis=0)
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# 6          Ghezzal  Algeria     forward       40      3       8        0
# 8         Halliche  Algeria    defender      270      2      94        4
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves
# 0        0
# 1        0
# 4        2
# 6        0
# 8        0
# ..     ...
# ...

# %%
df.minutes / 60
# Out:
# 0      0.266667
# 1      4.500000
# 2      1.233333
# 3      4.500000
# 4      1.500000
#          ...
# 590    0.066667
# 591    6.500000
# 592    5.933333
# 593    2.833333
# 594    0.750000
# Name: minutes, Length: 595, dtype: float64

# %%
df['hours'] = df.minutes / 60
df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves     hours
# 0        0  0.266667
# 1        0  4.500000
# 2        0  1.233333
# ...

# %%
pd.Series( range(1, 596))
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 590    591
# 591    592
# 592    593
# 593    594
# 594    595
# Length: 595, dtype: int64

# %%
df['number'] = pd.Series( range(1, 596))
df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves     hours  number
# 0        0  0.266667       1
# 1        0  4.500000       2
# ...

# %%
dic = {'surname':'Seth',
       'team':'Thailand',
       'position':'midfielder',
       'minutes':30}

# %%
new_row = pd.Series(dic)
new_row
# Out:
# surname           Seth
# team          Thailand
# position    midfielder
# minutes             30
# dtype: object

# %%
new_row.name = 595
new_row
# Out:
# surname           Seth
# team          Thailand
# position    midfielder
# minutes             30
# Name: 595, dtype: object

# %%
df.append(new_row)
# Out:
# /var/folders/g6/2f8wm3017f54d5k1qsxk012c0000gn/T/ipykernel_77089/3544121368.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row)
#            surname      team    position  minutes  shots  passes  tackles  \
# 0           Abdoun   Algeria  midfielder       16    0.0     6.0      0.0
# 1          Belhadj   Algeria    defender      270    1.0   146.0      8.0
# 2        Boudebouz   Algeria  midfielder       74    3.0    28.0      1.0
# 3        Bougherra   Algeria    defender      270    1.0    89.0     11.0
# 4         Chaouchi   Algeria  goalkeeper       90    0.0    17.0      0.0
# ..             ...       ...         ...      ...    ...     ...      ...
# 591         Howard       USA  goalkeeper      390    0.0    81.0      0.0
# 592  Jozy Altidore       USA     forward      356    8.0    84.0      2.0
# ...

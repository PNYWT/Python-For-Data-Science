# %%
import statsmodels.api as sm

# %%
macro_econ_data = sm.datasets.macrodata.load_pandas().data
macro_econ_data
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  ...      m1  tbilrate  unemp      pop  infl  realint
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045  ...   139.7      2.82    5.8  177.146  0.00     0.00
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301  ...   141.7      3.08    5.1  177.830  2.34     0.74
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260  ...   140.5      3.82    5.3  178.657  2.74     1.09
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052  ...   140.0      4.33    5.6  179.386  0.27     4.06
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199  ...   139.6      3.50    5.2  180.007  2.31     1.19
# ..      ...      ...        ...       ...       ...       ...  ...     ...       ...    ...      ...   ...      ...
# 198  2008.0      3.0  13324.600    9267.7  1990.693   991.551  ...  1474.7      1.17    6.0  305.270 -3.16     4.33
# ...

# %%
macro_econ_data.realgdp.plot()
# Out:
# <AxesSubplot:>

# %%
gdp_train = macro_econ_data.iloc[:-20, 2:8]
gdp_test = macro_econ_data.iloc[-20:, 2:8]

# %%
gdp_train
# Out:
#        realgdp  realcons   realinv  realgovt  realdpi     cpi
# 0     2710.349    1707.4   286.898   470.045   1886.9   28.98
# 1     2778.801    1733.7   310.859   481.301   1919.7   29.15
# 2     2775.488    1751.8   289.226   491.260   1916.4   29.35
# 3     2785.204    1753.7   299.356   484.052   1931.3   29.37
# 4     2847.699    1770.5   331.722   462.199   1955.5   29.54
# ..         ...       ...       ...       ...      ...     ...
# 178  11935.461    8312.1  1889.883   839.598   8935.4  184.90
# 179  12042.817    8358.0  1959.783   845.722   8986.4  186.30
# 180  12127.623    8437.6  1970.015   856.570   9025.9  187.40
# 181  12213.818    8483.2  2055.580   861.440   9115.0  189.10
# 182  12303.533    8555.8  2082.231   876.385   9175.9  190.80
#
# [183 rows x 6 columns]

# %%
realgdp_train = gdp_train

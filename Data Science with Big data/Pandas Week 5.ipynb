# %%
import pandas as pd
import numpy as np

# %%
path = "https://raw.githubusercontent.com/PNYWT/Python-For-Data-Science/main/Data%20Science%20with%20Big%20data/Datasets/players.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#      surname     team    position  minutes  shots  passes  tackles  saves  \
# 0     Abdoun  Algeria  midfielder       16      0       6        0      0
# 1    Belhadj  Algeria    defender      270      1     146        8      0
# 2  Boudebouz  Algeria  midfielder       74      3      28        1      0
# 3  Bougherra  Algeria    defender      270      1      89       11      0
# 4   Chaouchi  Algeria  goalkeeper       90      0      17        0      2
#
#    Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0         NaN         NaN  ...          NaN          NaN          NaN
# 1         NaN         NaN  ...          NaN          NaN          NaN
# 2         NaN         NaN  ...          NaN          NaN          NaN
# 3         NaN         NaN  ...          NaN          NaN          NaN
# 4         NaN         NaN  ...          NaN          NaN          NaN
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# ...

# %%
df = df.loc[:,:"saves"]

# %% [markdown]
# ### Sort Data

# %%
#ascending=False มากไปน้อย
#ascending=True น้อยไปมาก
df.sort_values("passes", ascending=False)
# Out:
#              surname         team    position  minutes  shots  passes  \
# 536             Xavi        Spain  midfielder      515      4     563
# 519         Busquets        Spain  midfielder      511      0     466
# 517           Alonso        Spain  midfielder      506      9     465
# 189   Schweinsteiger      Germany  midfielder      531      5     423
# 530            Pique        Spain    defender      540      2     402
# ..               ...          ...         ...      ...    ...     ...
# 542         Eggimann  Switzerland    defender        1      0       0
# 338           Barron  New Zealand  midfielder        1      0       0
# 292            Konno        Japan    defender        2      0       0
# 511  Lee Seung-Yeoul  South Korea     forward        3      0       0
# 504     Kim Dong-Jin  South Korea    defender        1      0       0
#
#      tackles  saves
# 536        6      0
# 519       15      0
# 517       18      0
# 189       23      0
# ...

# %%
df.sort_values(["passes", "shots"], ascending=[False,True]).head(20)
# Out:
#              surname         team    position  minutes  shots  passes  \
# 536             Xavi        Spain  midfielder      515      4     563
# 519         Busquets        Spain  midfielder      511      0     466
# 517           Alonso        Spain  midfielder      506      9     465
# 189   Schweinsteiger      Germany  midfielder      531      5     423
# 530            Pique        Spain    defender      540      2     402
# 183             Lahm      Germany    defender      540      0     360
# 28             Messi    Argentina     forward      450     21     321
# 520        Capdevila        Spain    defender      540      1     310
# 335       van Bommel  Netherlands  midfielder      540      2     307
# 195            Annan        Ghana  midfielder      510      4     307
# 62    Gilberto Silva       Brazil  midfielder      450      3     299
# 523          Iniesta        Spain  midfielder      437      8     299
# ...

# %%
df = df.set_index("surname")
df
# Out:
#                   team    position  minutes  shots  passes  tackles  saves
# surname
# Abdoun         Algeria  midfielder       16      0       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# [595 rows x 7 columns]

# %%
df.sort_index(ascending=True)
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# Abdoun               Algeria  midfielder       16      0       6        0
# Abe                    Japan  midfielder      351      0     101       14
# Abidal                France    defender      180      0      91        6
# Abou Diaby            France  midfielder      270      1     111        5
# Aboubakar           Cameroon     forward       46      2      16        0
# ...                      ...         ...      ...    ...     ...      ...
# de Zeeuw         Netherlands  midfielder       47      0      37        2
# van Bommel       Netherlands  midfielder      540      2     307       31
# van Bronckhorst  Netherlands    defender      540      1     271       10
# van Persie       Netherlands     forward      479     14     108        1
# von Bergen       Switzerland    defender      234      0      79        3
#
#                  saves
# surname
# Abdoun               0
# ...

# %% [markdown]
# ### Assignment Value

# %%
# df.loc["Algeria", "shots"] = 1.0

# %%
df.sort_index(ascending=True)
# Out:
#                         team    position  minutes  shots  passes  tackles  \
# surname
# Abdoun               Algeria  midfielder       16      0       6        0
# Abe                    Japan  midfielder      351      0     101       14
# Abidal                France    defender      180      0      91        6
# Abou Diaby            France  midfielder      270      1     111        5
# Aboubakar           Cameroon     forward       46      2      16        0
# ...                      ...         ...      ...    ...     ...      ...
# de Zeeuw         Netherlands  midfielder       47      0      37        2
# van Bommel       Netherlands  midfielder      540      2     307       31
# van Bronckhorst  Netherlands    defender      540      1     271       10
# van Persie       Netherlands     forward      479     14     108        1
# von Bergen       Switzerland    defender      234      0      79        3
#
#                  saves
# surname
# Abdoun               0
# ...

# %%
df.loc[df.minutes == 570, "minutes"] = 600 #broadcast ทุกแถวที่เข้าเงื่อนไข

# %%
df.sort_values("minutes", ascending=False)
# Out:
#                      team    position  minutes  shots  passes  tackles  saves
# surname
# Maxi Pereira      Uruguay  midfielder      600      5     182       15      0
# Arevalo Rios      Uruguay  midfielder      600      5     195       21      0
# Muslera           Uruguay  goalkeeper      600      0      75        0     16
# Perez             Uruguay  midfielder      567      2     252       34      0
# Forlan            Uruguay     forward      564     18     202        0      0
# ...                   ...         ...      ...    ...     ...      ...    ...
# Barron        New Zealand  midfielder        1      0       0        0      0
# Petras           Slovakia    defender        1      0       0        0      0
# Mesbah            Algeria  midfielder        1      0       1        0      0
# Eggimann      Switzerland    defender        1      0       0        0      0
# Kim Dong-Jin  South Korea    defender        1      0       0        0      0
#
# [595 rows x 7 columns]

# %%
df.loc[df.minutes == 600, "minutes"]
# Out:
# surname
# Arevalo Rios    600
# Maxi Pereira    600
# Muslera         600
# Name: minutes, dtype: int64

# %%
df.loc[df.minutes == 600, "minutes"] = [590,580,570]
df.sort_values("minutes", ascending=False)
# Out:
#                      team    position  minutes  shots  passes  tackles  saves
# surname
# Arevalo Rios      Uruguay  midfielder      590      5     195       21      0
# Maxi Pereira      Uruguay  midfielder      580      5     182       15      0
# Muslera           Uruguay  goalkeeper      570      0      75        0     16
# Perez             Uruguay  midfielder      567      2     252       34      0
# Forlan            Uruguay     forward      564     18     202        0      0
# ...                   ...         ...      ...    ...     ...      ...    ...
# Barron        New Zealand  midfielder        1      0       0        0      0
# Petras           Slovakia    defender        1      0       0        0      0
# Mesbah            Algeria  midfielder        1      0       1        0      0
# Eggimann      Switzerland    defender        1      0       0        0      0
# Kim Dong-Jin  South Korea    defender        1      0       0        0      0
#
# [595 rows x 7 columns]

# %% [markdown]
# ### Operations

# %%
df.shots
# Out:
# surname
# Abdoun           0
# Belhadj          1
# Boudebouz        3
# Bougherra        1
# Chaouchi         0
#                 ..
# Holden           0
# Howard           0
# Jozy Altidore    8
# Onyewu           1
# Torres           1
# Name: shots, Length: 595, dtype: int64

# %%
df.shots + 5 #broadcast ทุกแถวที่เข้าเงื่อนไข
# Out:
# surname
# Abdoun            5
# Belhadj           6
# Boudebouz         8
# Bougherra         6
# Chaouchi          5
#                  ..
# Holden            5
# Howard            5
# Jozy Altidore    13
# Onyewu            6
# Torres            6
# Name: shots, Length: 595, dtype: int64

# %% [markdown]
# ### บวก Index และเพิ่ม Column ใหม่

# %%
player = df.sample(5)

# %%
player
# Out:
#                 team    position  minutes  shots  passes  tackles  saves
# surname
# Gomez            USA     forward       85      4      18        0      0
# Ziani        Algeria  midfielder      240      5      93        6      0
# Jedinak    Australia  midfielder       16      0      15        0      0
# Honda          Japan  midfielder      390      8     143        5      0
# Carragher    England    defender      135      0      74        4      0

# %%
c1 = player.shots
c1
# Out:
# surname
# Gomez        4
# Ziani        5
# Jedinak      0
# Honda        8
# Carragher    0
# Name: shots, dtype: int64

# %%
c2 = player.tackles.sort_values(ascending=True)
c2
# Out:
# surname
# Gomez        0
# Jedinak      0
# Carragher    4
# Honda        5
# Ziani        6
# Name: tackles, dtype: int64

# %%
c1+c2
# Out:
# surname
# Carragher     4
# Gomez         4
# Honda        13
# Jedinak       0
# Ziani        11
# dtype: int64

# %%
player["tcklesAndShots"] = c1+c2

# %%
player
# Out:
#                 team    position  minutes  shots  passes  tackles  saves  \
# surname
# Gomez            USA     forward       85      4      18        0      0
# Ziani        Algeria  midfielder      240      5      93        6      0
# Jedinak    Australia  midfielder       16      0      15        0      0
# Honda          Japan  midfielder      390      8     143        5      0
# Carragher    England    defender      135      0      74        4      0
#
#            tcklesAndShots
# surname
# Gomez                   4
# Ziani                  11
# Jedinak                 0
# Honda                  13
# Carragher               4

# %% [markdown]
# ### case +index ที่มีจำนวน แถวไม่เท่ากันจะได้ NaN

# %%
c3 = c1.sample(3)
c3
# Out:
# surname
# Gomez        4
# Carragher    0
# Honda        8
# Name: shots, dtype: int64

# %%
c4 = c2.sample(5)
c4
# Out:
# surname
# Honda        5
# Carragher    4
# Ziani        6
# Gomez        0
# Jedinak      0
# Name: tackles, dtype: int64

# %%
c3+c4
# Out:
# surname
# Carragher     4.0
# Gomez         4.0
# Honda        13.0
# Jedinak       NaN
# Ziani         NaN
# dtype: float64

# %%
#วิธีแก้ ใช้ add() fill_value = 0 คือแทน row ที่ขาดไปให้เป็น 0 ก็จะสามารถบวกกันได้
c3.add(c4, fill_value = 0)
# Out:
# surname
# Carragher     4.0
# Gomez         4.0
# Honda        13.0
# Jedinak       0.0
# Ziani         6.0
# dtype: float64

# %% [markdown]
# ### case check NaN in data

# %%
c5 = c3+c4

# %%
c5
# Out:
# surname
# Carragher     4.0
# Gomez         4.0
# Honda        13.0
# Jedinak       NaN
# Ziani         NaN
# dtype: float64

# %%
# isna(), isnull(), มีค่าเหมือนกัน ไว้เช็ค data ที่เป็น NaN
# c5.isna()
c5.isnull()
# Out:
# surname
# Carragher    False
# Gomez        False
# Honda        False
# Jedinak       True
# Ziani         True
# dtype: bool

# %%
# ~c5.isna()
~c5.isnull()
# Out:
# surname
# Carragher     True
# Gomez         True
# Honda         True
# Jedinak      False
# Ziani        False
# dtype: bool

# %%
print("Data have value is not =",sum(c5.isnull()))
# Out:
# Data have value is not = 2

# %%
c5.loc[c5.isna()].shape[0]
# Out:
# 2

# %% [markdown]
# ### Calculate with Pandas

# %%
# cal column
df.shots.sum()
# Out:
# 1371

# %%
df.sum(numeric_only=True)
# Out:
# minutes    124304
# shots        1371
# passes      50290
# tackles      2494
# saves         397
# dtype: int64

# %%
df.shots.max()
# Out:
# 27

# %%
df.shots.min()
# Out:
# 0

# %%
df.shots.mean()
# Out:
# 2.3042016806722687

# %%
df.shots.rank()
# Out:
# 0      103.5
# 1      269.5
# 2      444.0
# 3      269.5
# 4      103.5
#        ...
# 590    103.5
# 591    103.5
# 592    560.0
# 593    269.5
# 594    269.5
# Name: shots, Length: 595, dtype: float64

# %%
# แสดง index ที่มีค่า shots สูงสุด
df.shots.idxmax()
# Out:
# 200

# %%
# แสดง index ที่มีค่า shots ต่ำสุด
df.shots.idxmin()
# Out:
# 0

# %%
# cal row
#sum(axis=True) axis คือ แกน True -> row, False -> Column
df.sum(axis=True,numeric_only= True)
# Out:
# surname
# Abdoun            22
# Belhadj          425
# Boudebouz        106
# Bougherra        371
# Chaouchi         109
#                 ...
# Holden             6
# Howard           485
# Jozy Altidore    450
# Onyewu           242
# Torres            78
# Length: 595, dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# minutes    208.914286
# shots        2.304202
# passes      84.521008
# tackles      4.191597
# saves        0.667227
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# minutes    590
# shots       27
# passes     563
# tackles     34
# saves       20
# dtype: int64

# %%
df.loc[:, "minutes": ] + 5
# Out:
#      minutes  shots  passes  tackles  saves       hour  pdNumber
# 0         21      5      11        5      5   5.266667         6
# 1        275      6     151       13      5   9.500000         7
# 2         79      8      33        6      5   6.233333         8
# 3        275      6      94       16      5   9.500000         9
# 4         95      5      22        5      7   6.500000        10
# ..       ...    ...     ...      ...    ...        ...       ...
# 590        9      5       7        5      5   5.066667       596
# 591      395      5      86        5     19  11.500000       597
# 592      361     13      89        7      5  10.933333       598
# 593      175      6      74        7      5   7.833333       599
# 594       50      6      37        5      5   5.750000       600
#
# [595 rows x 7 columns]

# %% [markdown]
# ### Drop/insert Column

# %%
df.iloc[:,:-1]
# Out:
#                   team    position  minutes  shots  passes  tackles
# surname
# Abdoun         Algeria  midfielder       16      0       6        0
# Belhadj        Algeria    defender      270      1     146        8
# Boudebouz      Algeria  midfielder       74      3      28        1
# Bougherra      Algeria    defender      270      1      89       11
# Chaouchi       Algeria  goalkeeper       90      0      17        0
# ...                ...         ...      ...    ...     ...      ...
# Holden             USA  midfielder        4      0       2        0
# Howard             USA  goalkeeper      390      0      81        0
# Jozy Altidore      USA     forward      356      8      84        2
# Onyewu             USA    defender      170      1      69        2
# Torres             USA  midfielder       45      1      32        0
#
# [595 rows x 6 columns]

# %%
# drop column
df.drop(["saves","tackles"], axis=True)
# Out:
#                   team    position  minutes  shots  passes
# surname
# Abdoun         Algeria  midfielder       16      0       6
# Belhadj        Algeria    defender      270      1     146
# Boudebouz      Algeria  midfielder       74      3      28
# Bougherra      Algeria    defender      270      1      89
# Chaouchi       Algeria  goalkeeper       90      0      17
# ...                ...         ...      ...    ...     ...
# Holden             USA  midfielder        4      0       2
# Howard             USA  goalkeeper      390      0      81
# Jozy Altidore      USA     forward      356      8      84
# Onyewu             USA    defender      170      1      69
# Torres             USA  midfielder       45      1      32
#
# [595 rows x 5 columns]

# %%
# drop index
df = df.reset_index()
df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves
# 0        0
# 1        0
# 2        0
# 3        0
# 4        2
# ..     ...
# ...

# %%
df.drop([2,3,4], axis=False)
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 5         Djebbour  Algeria     forward      123      3      19        1
# 6          Ghezzal  Algeria     forward       40      3       8        0
# 7        Guedioura  Algeria  midfielder       38      0      18        1
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves
# 0        0
# 1        0
# 5        0
# 6        0
# 7        0
# ..     ...
# ...

# %%
df["hour"] = df.minutes/60
df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves      hour
# 0        0  0.266667
# 1        0  4.500000
# 2        0  1.233333
# ...

# %%
pd.Series(range(1,596))
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 590    591
# 591    592
# 592    593
# 593    594
# 594    595
# Length: 595, dtype: int64

# %%
df["pdNumber"] = pd.Series(range(1,596))
df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves      hour  pdNumber
# 0        0  0.266667         1
# ...

# %%
# การเพิ่ม Row ต้องมีชื่อ Column ตรงกัน
dicHead = {"surname":"Hello Workd",
          "team":"Thailand",
          "position":"midfielder",
          "minutes":"999",
          "shots":"999",
          "passes":"999",
          "tackles":"55",
          "saves":"0"}

# %%
pd.Series(dicHead)
# Out:
# surname     Hello Workd
# team           Thailand
# position     midfielder
# minutes             999
# shots               999
# passes              999
# tackles              55
# saves                 0
# dtype: object

# %%
new_row = pd.Series(dicHead)
new_row
# Out:
# surname     Hello Workd
# team           Thailand
# position     midfielder
# minutes             999
# shots               999
# passes              999
# tackles              55
# saves                 0
# dtype: object

# %%
new_row.name = 595
new_row
# Out:
# surname     Hello Workd
# team           Thailand
# position     midfielder
# minutes             999
# shots               999
# passes              999
# tackles              55
# saves                 0
# Name: 595, dtype: object

# %%
df.append(new_row)
# Out:
# /var/folders/g6/2f8wm3017f54d5k1qsxk012c0000gn/T/ipykernel_21524/3544121368.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row)
#            surname      team    position minutes shots passes tackles saves  \
# 0           Abdoun   Algeria  midfielder      16     0      6       0     0
# 1          Belhadj   Algeria    defender     270     1    146       8     0
# 2        Boudebouz   Algeria  midfielder      74     3     28       1     0
# 3        Bougherra   Algeria    defender     270     1     89      11     0
# 4         Chaouchi   Algeria  goalkeeper      90     0     17       0     2
# ..             ...       ...         ...     ...   ...    ...     ...   ...
# 591         Howard       USA  goalkeeper     390     0     81       0    14
# 592  Jozy Altidore       USA     forward     356     8     84       2     0
# ...
